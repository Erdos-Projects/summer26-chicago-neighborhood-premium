# %%
#import packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#import median household income data for Albany Park

income_Albany_Park=pd.read_csv('median Household income/Albany_Park_Median_Household_Income.csv')

# %%
income_Albany_Park
# Out:
#      Category  Full population  Full population CI (low)  \
# 0   2006-2010     68196.912310              62664.945288
# 1   2007-2011     65726.514266              61105.020942
# 2   2008-2012     66277.496234              61434.068040
# 3   2009-2013     68956.558798              63998.520418
# 4   2010-2014     73910.616391              66558.443814
# 5   2011-2015     73135.052483              66050.467244
# 6   2012-2016     76593.809969              70482.971010
# 7   2013-2017     78001.900110              71227.328758
# 8   2014-2018     76691.290769              68648.970970
# 9   2015-2019     79134.474530              71895.465508
# 10  2016-2020     84572.844797              75072.587745
# 11  2017-2021     83232.060261              73868.665413
# 12  2018-2022     84276.043977              74904.058242
# 13  2019-2023     86061.871429              76310.666715
# 14  2020-2024     87083.511757              77020.478173
#
#     Full population CI (high)
# ...

# %% [markdown]
# The data is like a time seriex, except the time stamps are 5 year periods that overlap 4 years from one data point to the next. I'm not sure how to handle this.
#
# The data also comes with a confidence interval. I'm not sure if we need this or not.

# %%
#reading in housing properties sales activity for Albany Park

sales_Albany_Park=pd.read_csv('Housing Properties Sales Activity/Albany_Park_Housing_Sales_Count.csv')

# %%
sales_Albany_Park
# Out:
#     Category  Full population
# 0       2009              295
# 1       2010              328
# 2       2011              309
# 3       2012              381
# 4       2013              437
# 5       2014              413
# 6       2015              446
# 7       2016              517
# 8       2017              478
# 9       2018              450
# 10      2019              408
# 11      2020              412
# 12      2021              593
# 13      2022              448
# 14      2023              357

# %% [markdown]
# The housing sales data is a time series with new housing sales per year. This data's time stamp structure is different from the income data.
