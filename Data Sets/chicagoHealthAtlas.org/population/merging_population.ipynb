# %% [markdown]
# In this notebook, we combine the population data files into one data file.

# %%
#importing packages
import pandas as pd
import numpy as np

# %%
#reading in data files 
A=pd.read_csv('Population_starts_with_A.csv',index_col='Category')
BC=pd.read_csv('Population_starts_with_B_C.csv',index_col='Category')
DEF=pd.read_csv('Population_starts_with_D_E_F.csv',index_col='Category')
GHIJ=pd.read_csv('Population_starts_with_G_H_I_J.csv',index_col='Category')
KL=pd.read_csv('Population_starts_with_K_L.csv',index_col='Category')
MN=pd.read_csv('Population_starts_with_M_N.csv',index_col='Category')
OPR=pd.read_csv('Population_starts_with_O_P_R.csv',index_col='Category')
SU=pd.read_csv('Population_starts_with_S_U.csv',index_col='Category')
W=pd.read_csv('Population_starts_with_W.csv',index_col='Category')

# %%
#Concatenating dataframes
df_list=[A,BC,DEF,GHIJ,KL,MN,OPR,SU,W]
population=pd.concat(df_list,axis=1)
population
# Out:
#            Albany Park  Archer Heights  Armour Square      Ashburn  \
# Category
# 2006-2010  51813.07942     13043.67606    13633.64162  42556.43893
# 2007-2011  53839.57069     13113.67172    14290.50211  43109.85099
# 2008-2012  54015.51855     13522.03386    13751.55213  42958.13919
# 2009-2013  54136.85490     14217.40033    14153.50124  42990.93266
# 2010-2014  53052.35197     14085.47204    13885.14183  42980.50365
# 2011-2015  52208.54270     13383.12453    14047.22942  42921.88287
# 2012-2016  51701.42415     13357.41622    13679.62923  43448.49701
# 2013-2017  52123.08576     13266.38962    13447.80008  43962.54588
# 2014-2018  50474.74665     13178.41356    13768.80798  44160.60882
# 2015-2019  49941.76563     13816.24924    13585.42411  43537.90972
# 2016-2020  49438.25315     13612.35166    13395.54933  43084.57334
# 2017-2021  48822.58836     13669.57049    13283.33538  44401.50793
# 2018-2022  47854.87510     13948.25753    13177.96891  42925.94412
# ...

# %%
#Exporting data to a single csv
population.to_csv('population_merged.csv')
